# %% [markdown]
# ## Criar DataFrames com base nos Datasets

# %%
import pandas as pd

# %%
#Carregar Dataframes de Clientes (customers)
df_customers = pd.read_csv('./datasets/churn_customers.csv')

# %%
# Mostrar os 5 primeiros registros do DataFrame
df_customers.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Mostrar os 5 ultimos registros do DataFrame
df_customers.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# Mostrar estrutura / schema DataFrame
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   str
#  1   gender         7043 non-null   str
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   str
#  4   Dependents     7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %%
#Carregar Dataframes de Serviços (services)
df_services = pd.read_csv('./datasets/churn_services.csv')

# %%
# Mostrar os 5 primeiros registros do DataFrame
df_services.head(5)
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
# Mostrar os 5 ultimos registros do DataFrame
df_services.tail(5)
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 7038  6840-RESVB          Yes               Yes             DSL
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies
# 7038             Yes
# 7039             Yes
# 7040              No
# 7041              No
# 7042             Yes

# %%
# Mostrar estrutura / schema DataFrame
df_services.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   PhoneService      7043 non-null   str
#  2   MultipleLines     7043 non-null   str
#  3   InternetService   7043 non-null   str
#  4   OnlineSecurity    7043 non-null   str
#  5   OnlineBackup      7043 non-null   str
#  6   DeviceProtection  7043 non-null   str
#  7   TechSupport       7043 non-null   str
#  8   StreamingTV       7043 non-null   str
#  9   StreamingMovies   7043 non-null   str
# dtypes: str(10)
# memory usage: 550.4 KB

# %%
#Carregar Dataframes de Contratos (contracts)
df_contracts = pd.read_csv('./datasets/churn_contracts.csv')

# %%
# Mostrar os 5 primeiros registros do DataFrame
df_contracts.head(5)
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
# Mostrar os 5 ultimos registros do DataFrame
df_contracts.tail(5)
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 7038               Mailed check           84.80       1990.5    No
# 7039    Credit card (automatic)          103.20       7362.9    No
# 7040           Electronic check           29.60       346.45    No
# 7041               Mailed check           74.40        306.6   Yes
# 7042  Bank transfer (automatic)          105.65       6844.5    No

# %%
# Mostrar estrutura / schema DataFrame
df_contracts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   str
#  3   PaperlessBilling  7043 non-null   str
#  4   PaymentMethod     7043 non-null   str
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   str
#  7   Churn             7043 non-null   str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 440.3 KB

# %% [markdown]
# ## Trasnformação de Dados

# %%
# Transformar coluna TotalCharges de String para Float - Abordagem 1 com astype

df_contracts.TotalCharges = df_contracts.TotalCharges.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 # Transformar coluna TotalCharges de String para Float - Abordagem 1 com astype
# ----> 3 df_contracts.TotalCharges = df_contracts.TotalCharges.astype(float)
#
# File ~/.local/share/virtualenvs/EDA-fMQ4_9d-/lib/python3.11/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# ...

# %%
# Transformar coluna TotalCharges de String para Float - Abordagem 2 com to_numeric
df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2478, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Transformar coluna TotalCharges de String para Float - Abordagem 2 com to_numeric
# ----> 2 df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges)
#
# File ~/.local/share/virtualenvs/EDA-fMQ4_9d-/lib/python3.11/site-packages/pandas/core/tools/numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233     values = ensure_object(values)
#     234     coerce_numeric = errors != "raise"
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
# ...

# %%
# Transformar coluna TotalCharges de String para Float - Abordagem 3 com to_numeric com coerce (trasforma em null quando não for valido a transformação)
df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges, errors = 'coerce')

# %%
# Mostrar estrutura / schema DataFrame
df_contracts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   str
#  3   PaperlessBilling  7043 non-null   str
#  4   PaymentMethod     7043 non-null   str
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 440.3 KB

# %% [markdown]
# Após a transformação da coluna TotalCharges do Dataframe Contracts , a coluna passou a ter valores ausentes (missing values)

# %% [markdown]
# ## Renomear Colunas

# %%
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   str
#  1   gender         7043 non-null   str
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   str
#  4   Dependents     7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %%
# Renomear coluna no DataFrame, usando raname e dicionario
df_customers.rename(columns={'SeniorCitizen':'Above65yo'})
# Out:
#       customerID  gender  Above65yo Partner Dependents
# 0     7590-VHVEG  Female          0     Yes         No
# 1     5575-GNVDE    Male          0      No         No
# 2     3668-QPYBK    Male          0      No         No
# 3     7795-CFOCW    Male          0      No         No
# 4     9237-HQITU  Female          0      No         No
# ...          ...     ...        ...     ...        ...
# 7038  6840-RESVB    Male          0     Yes        Yes
# 7039  2234-XADUH  Female          0     Yes        Yes
# 7040  4801-JZAZL  Female          0     Yes        Yes
# 7041  8361-LTMKD    Male          1     Yes         No
# 7042  3186-AJIEK    Male          0      No         No
#
# [7043 rows x 5 columns]

# %%
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   str
#  1   gender         7043 non-null   str
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   str
#  4   Dependents     7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %%
# Criar um DataFrame novo com base nas colunas renomeadas 
df_customers_renamed = df_customers.rename(columns={'SeniorCitizen':'Above65yo'})

# %%
df_customers_renamed.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   str
#  1   gender      7043 non-null   str
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   str
#  4   Dependents  7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %%
# Aplicar o resultado do reaname no próprio DataFrame
df_customers.rename(columns={'SeniorCitizen':'Above65yo'}, inplace = True )

# %%
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   str
#  1   gender      7043 non-null   str
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   str
#  4   Dependents  7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %%
# Rename usando listas - Modificar todos os nome de colunas

df_customers.columns = ['IDCliente', 'Genero', 'Mais65anos', 'TemParceiro', 'TemDependentes']

# %%
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   str
#  1   Genero          7043 non-null   str
#  2   Mais65anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   str
#  4   TemDependentes  7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %% [markdown]
# ## Unificando DataFrames de Customers, Services e Contracts

# %%
# Contar quantidade de registros por DataFrame 
len(df_customers)
# Out:
# 7043

# %%
len(df_services)
# Out:
# 7043

# %%
len(df_contracts)
# Out:
# 7043

# %%
# Renomear colunas em comun dos Dataframes para realizar os merges 
df_services.rename(columns={"customerID": "IDCliente"}, inplace=True)

# %%
df_services.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   str
#  1   PhoneService      7043 non-null   str
#  2   MultipleLines     7043 non-null   str
#  3   InternetService   7043 non-null   str
#  4   OnlineSecurity    7043 non-null   str
#  5   OnlineBackup      7043 non-null   str
#  6   DeviceProtection  7043 non-null   str
#  7   TechSupport       7043 non-null   str
#  8   StreamingTV       7043 non-null   str
#  9   StreamingMovies   7043 non-null   str
# dtypes: str(10)
# memory usage: 550.4 KB

# %%
# Unificar DataFrame costumers com services, criando um terceiro DataFrame

df_temp = df_customers.merge(df_services, on =['IDCliente'])

# %%
#Mostrar estrutura

df_temp.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   str
#  1   Genero            7043 non-null   str
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   str
#  4   TemDependentes    7043 non-null   str
#  5   PhoneService      7043 non-null   str
#  6   MultipleLines     7043 non-null   str
#  7   InternetService   7043 non-null   str
#  8   OnlineSecurity    7043 non-null   str
#  9   OnlineBackup      7043 non-null   str
#  10  DeviceProtection  7043 non-null   str
#  11  TechSupport       7043 non-null   str
#  12  StreamingTV       7043 non-null   str
#  13  StreamingMovies   7043 non-null   str
# dtypes: int64(1), str(13)
# memory usage: 770.5 KB

# %%
# Unificar o df_temp com Contracts, usando colunas de junçao com nomes distintos

df_churn_temp = df_temp.merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn_temp.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   str
#  1   Genero            7043 non-null   str
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   str
#  4   TemDependentes    7043 non-null   str
#  5   PhoneService      7043 non-null   str
#  6   MultipleLines     7043 non-null   str
#  7   InternetService   7043 non-null   str
#  8   OnlineSecurity    7043 non-null   str
#  9   OnlineBackup      7043 non-null   str
#  10  DeviceProtection  7043 non-null   str
#  11  TechSupport       7043 non-null   str
#  12  StreamingTV       7043 non-null   str
#  13  StreamingMovies   7043 non-null   str
#  14  customerID        7043 non-null   str
#  15  tenure            7043 non-null   int64
#  16  Contract          7043 non-null   str
# ...

# %%
# Unificar os tres DataFrame ao mesmo tempo com colunas com nomes diferentes

df_churn = df_customers.merge(df_services, on = ['IDCliente']).merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   str
#  1   Genero            7043 non-null   str
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   str
#  4   TemDependentes    7043 non-null   str
#  5   PhoneService      7043 non-null   str
#  6   MultipleLines     7043 non-null   str
#  7   InternetService   7043 non-null   str
#  8   OnlineSecurity    7043 non-null   str
#  9   OnlineBackup      7043 non-null   str
#  10  DeviceProtection  7043 non-null   str
#  11  TechSupport       7043 non-null   str
#  12  StreamingTV       7043 non-null   str
#  13  StreamingMovies   7043 non-null   str
#  14  customerID        7043 non-null   str
#  15  tenure            7043 non-null   int64
#  16  Contract          7043 non-null   str
# ...

# %%
#Removendo coluna de um DataFrame
df_churn.drop(['customerID'], axis = 1 , inplace = True)

# %%
df_churn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   str
#  1   Genero            7043 non-null   str
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   str
#  4   TemDependentes    7043 non-null   str
#  5   PhoneService      7043 non-null   str
#  6   MultipleLines     7043 non-null   str
#  7   InternetService   7043 non-null   str
#  8   OnlineSecurity    7043 non-null   str
#  9   OnlineBackup      7043 non-null   str
#  10  DeviceProtection  7043 non-null   str
#  11  TechSupport       7043 non-null   str
#  12  StreamingTV       7043 non-null   str
#  13  StreamingMovies   7043 non-null   str
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %% [markdown]
# # Detecçao de valores ausentes

# %%
# Detectar valores ausentes em todas as colunas de um dataframe
df_churn.isna().sum()
# Out:
# IDCliente            0
# Genero               0
# Mais65anos           0
# TemParceiro          0
# TemDependentes       0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Detectar valores ausentes em tuma  coluna de um dataframe
df_churn.TotalCharges.isna().sum()
# Out:
# np.int64(11)

# %%
# Quantas linhas tem pelo menos uma coluna com um valor ausente
df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
# ...

# %%
# Quatas colunas tem pelo menos um valor ausente
df_churn.isna().any(axis=0).sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## Remover valores ausentes

# %%
# Remover de forma direta e especifica a coluna que possui valores aussentes
df_churn.drop(columns=['TotalCharges'])
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas com valores ausentes 

df_churn.dropna(axis=1)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas onde todos os valores são ausentes

df_churn.dropna(axis=1, how='all')
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover as linhascom valores ausentes

df_churn.dropna(axis=0)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover linhas onde todos os valores são ausentes

df_churn.dropna(axis=0, how='all')
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Inputação de Valores Ausentes

# %%
# Peencher todos os valores ausentes com 0

df_churn.fillna(0)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Prencher valores padrão conforme a coluna 
df_churn.fillna(value={'TotalCharges': 0, 'Genero': 'Não declarado'})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher todos os valores ausentes de uma coluna com a media

media_TotalCharges = df_churn.TotalCharges.mean()

# %%
media_TotalCharges
# Out:
# np.float64(2283.3004408418656)

# %%
df_churn.fillna(value={'TotalCharges': media_TotalCharges,})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...
